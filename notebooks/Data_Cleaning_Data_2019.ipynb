# %% [markdown]
# # Data Cleaning 2019 Plastic Pollution Data

# %%
import pandas as pd

# %%
def drop_not_needed_columns(df: pd.DataFrame) -> pd.DataFrame:
    columns_to_drop = ['Flag Codes', 'Flags', 'TIME']

    # Check if columns exist in the DataFrame before dropping
    existing_columns = [col for col in columns_to_drop if col in df.columns]
    if existing_columns:
        df.drop(columns=existing_columns, inplace=True)

    return df

# %%
waste_df = pd.read_csv('../data/raw_data/plastic_waste_2019.csv')
# drop not needed columns
waste_df = drop_not_needed_columns(waste_df)
waste_df.drop(columns=(['PLASTICS_POLYMER','PLASTICS_APPLICATIONS']),inplace=True)
# apply common style
waste_df.columns = waste_df.columns.str.lower().str.replace(" ","_")
# renaming some column names
waste_df.columns = ['location_code', 'location','plastics_polymer', 'plastics_applications', 'total_waste' ]

display(waste_df.head())
waste_df.shape
# Out:
#   location_code            location plastics_polymer plastics_applications  \
# 0           OAM  Other OECD America            Other                 Other
# 1           OAM  Other OECD America      LDPE, LLDPE                 Other
# 2           OAM  Other OECD America             HDPE                 Other
# 3           OAM  Other OECD America               PS                 Other
# 4           OAM  Other OECD America              PVC                 Other
#
#    total_waste
# 0     1.024199
# 1     0.168113
# 2     0.132488
# 3     0.061802
# 4     0.209497
# (1410, 5)

# %%
for col in waste_df.columns:
    print(col)
    print(waste_df[col].unique())
# Out:
# location_code
# ['OAM' 'O22' 'OE6' 'OPA' 'OCE' 'LAM' 'EU5' 'RAN' 'MEN' 'OAF' 'ODA' 'USA1'
#  'CAN1' 'CHN1' 'IND1']
# location
# ['Other OECD America' 'OECD EU ' 'OECD Non-EU' 'OECD Asia' 'OECD Oceania'
#  'Latin America' 'Other EU' 'Other Eurasia' 'Middle East & North Africa'
#  'Other Africa' 'Other non-OECD Asia' 'United States' 'Canada' 'China'
#  'India']
# plastics_polymer
# ['Other' 'LDPE, LLDPE' 'HDPE' 'PS' 'PVC' 'PUR' 'Fibres' 'Bioplastics'
#  'ABS, ASA, SAN' 'PP' 'PET' 'Marine coatings' 'Road marking coatings'
#  'Elastomers (tyres)' 'Total']
# plastics_applications
# ['Other' 'Packaging' 'Consumer & institutional Products'
#  'Building & construction' 'Electrical/electronics'
#  'Transportation - other' 'Marine coatings' 'Industrial/machinery'
#  'Personal care products' 'Textile sector - clothing'
#  'Textile sector - others' 'Road marking' 'Transportation - tyres' 'Total']
# total_waste
# [ 1.02419888  0.16811306  0.13248803 ...  0.11757103  0.32989009
#  18.51841148]

# %%
#create unique key
waste_df['primary_key'] = waste_df['location_code']+waste_df['plastics_polymer']+waste_df['plastics_applications']

# %%
#waste_df2 = waste_df.pivot_table(index=('location_code','location'),columns=['plastics_polymer','plastics_applications'], values='total_waste', aggfunc=sum)#.reset_index()
#waste_df_unstacked = waste_df2.stack().reset_index().rename_axis(None, axis=1)
#data_pivot['Location'].unique()
#waste_df_unstacked

# %%
waste_df.isnull().sum()
# Out:
# location_code            0
# location                 0
# plastics_polymer         0
# plastics_applications    0
# total_waste              0
# primary_key              0
# dtype: int64

# %%
leakage = pd.read_csv('../data/raw_data/plastic_leakage_2019.csv')
# drop not needed columns
drop_not_needed_columns(leakage)
leakage.drop(columns=(['PLASTIC_CATEGORY','PLASTIC_SOURCES']),inplace=True)
# apply common style
leakage.columns = leakage.columns.str.lower().str.replace(" ","_")
# renaming some column names
leakage.columns = ['location_code', 'location','plastic_category', 'plastic_source', 'total_leakage' ]

display(leakage.head())
leakage.shape
# Out:
#   location_code            location plastic_category      plastic_source  \
# 0           OAM  Other OECD America    Macroplastics  Total Macroplastic
# 1           OAM  Other OECD America    Macroplastics   Marine activities
# 2           OAM  Other OECD America    Macroplastics           Littering
# 3           OAM  Other OECD America    Macroplastics          Mismanaged
# 4           OAM  Other OECD America    Microplastics  Total Microplastic
#
#    total_leakage
# 0       0.558108
# 1       0.004240
# 2       0.040186
# 3       0.513682
# 4       0.074018
# (225, 5)

# %%
for col in leakage.columns:
    print(col)
    print(leakage[col].unique())
# Out:
# location_code
# ['OAM' 'O22' 'OE6' 'OPA' 'OCE' 'LAM' 'EU5' 'RAN' 'MEN' 'OAF' 'ODA' 'USA1'
#  'CAN1' 'CHN1' 'IND1']
# location
# ['Other OECD America' 'OECD EU ' 'OECD Non-EU' 'OECD Asia' 'OECD Oceania'
#  'Latin America' 'Other EU' 'Other Eurasia' 'Middle East & North Africa'
#  'Other Africa' 'Other non-OECD Asia' 'United States' 'Canada' 'China'
#  'India']
# plastic_category
# ['Macroplastics' 'Microplastics']
# plastic_source
# ['Total Macroplastic' 'Marine activities' 'Littering' 'Mismanaged'
#  'Total Microplastic' 'Primary pellets' 'Microbeads' 'Textile wash'
#  'Tyre abrasion' 'Brake dust' 'Road markings' 'Marine coatings'
#  'Artificial turf' 'Microplastics dust' 'WW sludge']
# total_leakage
# [5.58107760e-01 4.23992200e-03 4.01863350e-02 5.13681502e-01
#  7.40176150e-02 8.63958700e-03 1.07708000e-04 1.27706000e-04
#  1.73394290e-02 1.14000600e-03 1.03061500e-02 1.32969200e-03
#  2.04309400e-03 1.99852170e-02 1.29990260e-02 5.50793731e-01
#  1.32822210e-02 9.24726710e-02 4.45038839e-01 2.81274891e-01
#  2.20357040e-02 3.36787000e-04 5.16640000e-04 7.05788100e-02
#  4.77949100e-03 2.05748230e-02 5.74452900e-03 9.19303300e-03
#  2.73108900e-02 1.20204183e-01 3.22853343e-01 1.11516390e-02
#  3.11914000e-02 2.80510304e-01 7.53515690e-02 7.25418900e-03
#  1.69809000e-04 2.06276000e-04 1.00150760e-02 6.14476000e-04
#  6.83871000e-03 1.93815400e-03 3.12669100e-03 1.02806600e-02
#  3.49075280e-02 9.02175610e-02 1.25147410e-02 2.45655960e-02
#  5.31372240e-02 7.66067680e-02 3.91226800e-03 1.54471000e-04
#  2.17493000e-04 1.47799880e-02 9.95851000e-04 6.58770900e-03
#  7.04600000e-06 8.66037000e-04 6.99809400e-03 4.20878110e-02
#  3.09993910e-02 3.33197400e-03 3.18676900e-03 2.44806470e-02
#  1.72424840e-02 7.85499000e-04 5.81340000e-05 1.13879000e-04
#  4.44489300e-03 2.93645000e-04 3.08549000e-04 1.37269000e-04
#  1.81308000e-04 1.25295000e-03 9.66635700e-03 1.81672298e+00
#  9.91785000e-03 7.01473210e-02 1.73665781e+00 1.76396900e-01
#  1.74123430e-02 1.37635000e-04 1.57693000e-04 6.25958200e-02
# 3           OAM  Other OECD America                 Other               PS
# 4           OAM  Other OECD America                 Other              PVC
#
#    total_use
# 0   1.065140
# 1   0.179820
# 2   0.132932
# 3   0.062225
# 4   0.208997
# (1398, 5)

# %%
for col in use.columns:
    print(col)
    print(use[col].unique())
# Out:
# location_code
# ['OAM' 'O22' 'OE6' 'OPA' 'OCE' 'LAM' 'EU5' 'RAN' 'MEN' 'OAF' 'ODA' 'USA1'
#  'CAN1' 'CHN1' 'IND1']
# location
# ['Other OECD America' 'OECD EU ' 'OECD Non-EU' 'OECD Asia' 'OECD Oceania'
#  'Latin America' 'Other EU' 'Other Eurasia' 'Middle East & North Africa'
#  'Other Africa' 'Other non-OECD Asia' 'United States' 'Canada' 'China'
#  'India']
# plastics_applications
# ['Other' 'Packaging' 'Consumer & institutional Products'
#  'Building & construction' 'Electrical/electronics'
#  'Transportation - other' 'Marine coatings' 'Industrial/machinery'
#  'Personal care products' 'Textile sector - clothing'
#  'Textile sector - others' 'Road marking' 'Transportation - tyres' 'Total']
# plastics_polymer
# ['Other' 'LDPE, LLDPE' 'HDPE' 'PS' 'PVC' 'PUR' 'Fibres' 'Bioplastics'
#  'ABS, ASA, SAN' 'Total' 'PP' 'PET' 'Marine coatings'
#  'Road marking coatings' 'Elastomers (tyres)']
# total_use
# [ 1.06514   0.17982   0.132932 ...  0.151305  0.55751  29.333368]

# %%
#create unique key
use['primary_key'] = use['location_code']+use['plastics_polymer']+use['plastics_applications']

# %%
use
# Out:
#      location_code            location plastics_applications  \
# 0              OAM  Other OECD America                 Other
# 1              OAM  Other OECD America                 Other
# 2              OAM  Other OECD America                 Other
# 3              OAM  Other OECD America                 Other
# 4              OAM  Other OECD America                 Other
# ...            ...                 ...                   ...
# 1393          IND1               India                 Total
# 1394          IND1               India                 Total
# 1395          IND1               India                 Total
# 1396          IND1               India                 Total
# 1397          IND1               India                 Total
#
#            plastics_polymer  total_use                     primary_key
# 0                     Other   1.065140                   OAMOtherOther
# 1               LDPE, LLDPE   0.179820             OAMLDPE, LLDPEOther
# 2                      HDPE   0.132932                    OAMHDPEOther
# 3                        PS   0.062225                      OAMPSOther
# 4                       PVC   0.208997                     OAMPVCOther
# ...                     ...        ...                             ...
# 1393  Road marking coatings   0.045302  IND1Road marking coatingsTotal
# 1394     Elastomers (tyres)   0.553813     IND1Elastomers (tyres)Total
# 1395            Bioplastics   0.151305            IND1BioplasticsTotal
# 1396          ABS, ASA, SAN   0.557510          IND1ABS, ASA, SANTotal
# 1397                  Total  29.333368                  IND1TotalTotal
#
# [1398 rows x 6 columns]

# %%
# merge waste and use df
plastic_df = pd.merge(waste_df, use, on='primary_key', how='left')

# %%
plastic_df
# Out:
#      location_code            location       plastics_polymer  \
# 0              OAM  Other OECD America                  Other
# 1              OAM  Other OECD America            LDPE, LLDPE
# 2              OAM  Other OECD America                   HDPE
# 3              OAM  Other OECD America                     PS
# 4              OAM  Other OECD America                    PVC
# ...            ...                 ...                    ...
# 1405          IND1               India  Road marking coatings
# 1406          IND1               India     Elastomers (tyres)
# 1407          IND1               India            Bioplastics
# 1408          IND1               India          ABS, ASA, SAN
# 1409          IND1               India                  Total
#
#      plastics_applications  total_waste                     primary_key  \
# 0                    Other     1.024199                   OAMOtherOther
# 1                    Other     0.168113             OAMLDPE, LLDPEOther
# 2                    Other     0.132488                    OAMHDPEOther
# 3                    Other     0.061802                      OAMPSOther
# 4                    Other     0.209497                     OAMPVCOther
# ...                    ...          ...                             ...
# 1405                 Total     0.033476  IND1Road marking coatingsTotal
# 1406                 Total     0.199958     IND1Elastomers (tyres)Total
# 1407                 Total     0.117571            IND1BioplasticsTotal
# 1408                 Total     0.329890          IND1ABS, ASA, SANTotal
# 1409                 Total    18.518411                  IND1TotalTotal
#
#       total_use
# 0      1.065140
# 1      0.179820
# 2      0.132932
# 3      0.062225
# 4      0.208997
# ...         ...
# 1405   0.045302
# 1406   0.553813
# 1407   0.151305
# 1408   0.557510
# 1409  29.333368
#
# [1410 rows x 7 columns]

# %%
plastic_df_polym = plastic_df.pivot_table(index=('location_code','location'),columns=['plastics_polymer'], values=['total_waste'], aggfunc='sum').reset_index()
#data_pivot['Location'].unique()

# %%
plastic_df.columns
# Out:
# Index(['location_code', 'location', 'plastics_polymer',
#        'plastics_applications', 'total_waste', 'primary_key', 'total_use'],
#       dtype='object')

# %% [markdown]
# ##### Checking NaN values and finding method to replace them

# %%
plastic_df[(plastic_df['total_use'].isna()==True)]
# Out:
#     location_code                    location    plastics_polymer  \
# 252           OPA                   OECD Asia     Marine coatings
# 263           OPA                   OECD Asia  Elastomers (tyres)
# 587           MEN  Middle East & North Africa                HDPE
# 588           MEN  Middle East & North Africa                  PP
# 659           OAF                Other Africa  Elastomers (tyres)
#
#       plastics_applications   total_waste  \
# 252         Marine coatings  7.045900e-05
# 263  Transportation - tyres  9.055140e-04
# 587  Personal care products  4.530000e-07
# 588  Personal care products  1.200000e-08
# 659  Transportation - tyres  9.974000e-05
#
#                                      primary_key  total_use
# 252            OPAMarine coatingsMarine coatings        NaN
# 263  OPAElastomers (tyres)Transportation - tyres        NaN
# 587                MENHDPEPersonal care products        NaN
# 588                  MENPPPersonal care products        NaN
# 659  OAFElastomers (tyres)Transportation - tyres        NaN

# %%
plastic_df[['total_use']].describe()
# Out:
#         total_use
# count  985.000000
# mean     0.466747
# std      0.998876
# min      0.000003
# 25%      0.024576
# 50%      0.122982
# 75%      0.412638
# max      7.662625

# %%
#we can either leave the the NaNs as 0 or replace it with the finding out the ratio of incinerated in other africa in 2019 to total waste and use this ratio to replace nans
#we need to update then as well the total rows

# %%
plastic_df.columns
# Out:
# Index(['location_code', 'location', 'plastics_polymer',
#        'plastics_applications', 'total_waste', 'primary_key', 'total_use'],
#       dtype='object')

# %%
# finally, reorder column oder
plastic_df = plastic_df.reindex(columns=['primary_key','location_code', 'location', 'plastics_polymer',
       'plastics_applications', 'total_waste', 'total_use'])

# %%
plastic_df.head(2)
# Out:
#            primary_key location_code            location plastics_polymer  \
# 0        OAMOtherOther           OAM  Other OECD America            Other
# 1  OAMLDPE, LLDPEOther           OAM  Other OECD America      LDPE, LLDPE
#
#   plastics_applications  total_waste  total_use
# 0                 Other     1.024199    1.06514
# 1                 Other     0.168113    0.17982

# %%
import os  
os.makedirs('../data/cleaned_data', exist_ok=True)  
plastic_df.to_csv('../data/cleaned_data/cleaned_data_2019.csv')
